# %%
import pandas as pd

# %%
df = pd.read_csv('turkey_climate_data_2017_2020.csv')
df
# Out:
#            STATION         NAME  LATITUDE  LONGITUDE  ELEVATION        DATE  \
# 0      TUM00017204      MUS, TU    38.733     41.517     1320.0  2017-01-01
# 1      TUM00017204      MUS, TU    38.733     41.517     1320.0  2017-01-02
# 2      TUM00017204      MUS, TU    38.733     41.517     1320.0  2017-01-03
# 3      TUM00017204      MUS, TU    38.733     41.517     1320.0  2017-01-04
# 4      TUM00017204      MUS, TU    38.733     41.517     1320.0  2017-01-05
# ...            ...          ...       ...        ...        ...         ...
# 75649  TUM00017080  CANKIRI, TU    40.600     33.617      751.0  2020-12-28
# 75650  TUM00017080  CANKIRI, TU    40.600     33.617      751.0  2020-12-29
# 75651  TUM00017080  CANKIRI, TU    40.600     33.617      751.0  2020-12-30
# 75652  TUM00017080  CANKIRI, TU    40.600     33.617      751.0  2020-12-31
# 75653  TUM00017080  CANKIRI, TU    40.600     33.617      751.0  2021-01-01
#
#        PRCP  SNWD  TAVG  TMAX  TMIN
# ...

# %%
df.isnull().sum()
# Out:
# STATION          0
# NAME             0
# LATITUDE         0
# LONGITUDE        0
# ELEVATION        0
# DATE             0
# PRCP         26744
# SNWD         70828
# TAVG             0
# TMAX         43747
# TMIN         20725
# dtype: int64

# %%
df["NAME"].unique()
# Out:
# array(['MUS, TU', 'BINGOL, TU', 'ELAZIG, TU', 'HAKKARI, TU', 'TOKAT, TU',
#        'CORUM, TU', 'BATMAN, TU', 'KONYA, TU', 'KASTAMONU, TU',
#        'ARTVIN, TU', 'GUMUSHANE, TU', 'EDIRNE, TU', 'MUGLA, TU',
#        'ERZINCAN, TU', 'KARS, TU', 'ANKARA CENTRAL, TU', 'ERZURUM, TU',
#        'NIGDE, TU', 'ISKENDERUN, TU', 'KAHRAMANMARAS, TU', 'TEKIRDAG, TU',
#        'SIIRT, TU', 'ISPARTA, TU', 'AGRI, TU', 'SIVAS, TU', 'FINIKE, TU',
#        'SINOP, TU', 'MERSIN, TU', 'YOZGAT, TU', 'VAN, TU', 'OGUZELI, TU',
#        'ADAPAZARI, TU', 'ANTALYA, TU', 'USAK, TU', 'ADIYAMAN, TU',
#        'ZONGULDAK, TU', 'IZMIR GUZELYALI, TU', 'NEVSEHIR, TU',
#        'SANLIURFA, TU', 'BOLU, TU', 'AFYON, TU', 'BURSA, TU',
#        'DENIZLI, TU', 'SAMSUN, TU', 'BALIKESIR, TU', 'AYDIN, TU',
#        'CANAKKALE, TU', 'GIRESUN, TU', 'KUTAHYA, TU', 'KIRSEHIR, TU',
#        'DIYARBAKIR, TU', 'CANKIRI, TU'], dtype=object)
